# %%
# Get the latest price of a security

from pmdata import get_datapoint
from datetime import date

get_datapoint("BCHN.LSE", "adjusted_close", date(2022,11,29))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\dev\PortfolioManager\backend\api\pmdata.py:107, in get_fx_timeseries(currency, datapoint_name, fill_method, use_cache)
#     106 path = os.path.join(get_fx_database(), currency, datapoint_name)
# --> 107 a = np.load(path+'.npy')
#     108 #Read start and end dates
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\sebma\\dev\\PortfolioManager\\backend\\db/FX\\BCHN.LSE\\adjusted_close.npy'
#
# During handling of the above exception, another exception occurred:
#
# PMException                               Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       3 from pmdata import get_datapoint
#       4 from datetime import date
# ----> 6 get_datapoint("BCHN.LSE", "adjusted_close", date(2022,11,29))
#
# File ~\dev\PortfolioManager\backend\api\pmdata.py:128, in get_datapoint(full_ticker, datapoint_name, date)
#     127 def get_datapoint(full_ticker:str, datapoint_name:str, date:date)->np.float32:
# --> 128     return get_fx_timeseries(full_ticker, datapoint_name).get(date)
#
# File ~\dev\PortfolioManager\backend\api\pmdata.py:122, in get_fx_timeseries(currency, datapoint_name, fill_method, use_cache)
#     119     return toreturn
#     121 except FileNotFoundError:
# --> 122     raise PMException("Could not find time series for currency {currency}".format(currency = currency))
#
# PMException: Could not find time series for currency BCHN.LSE

# %%
# Sample time series
# This sample code loads 30+ years of data from Goodyear and displays its adjusted close informatoin
# Notice how weekend data is forward filled.
# You can play with the dates to zoom in and out in the data

from pmdata import get_timeseries, get_ticker
import matplotlib.pyplot as plt
import pandas as pd

# This is how we are getting the time series of a stock
ts = get_timeseries('GT.US', "adjusted_close")
ticker = get_ticker('GT.US')
# We are getting access to the underlying Numpy array in order to graph it
vector = ts.get_full_time_series()
# We are getting access to the dates in order to display them on the horizontal axis
dates = pd.date_range(ts.get_start_date(), ts.get_end_date(), freq='D')
# And we graph the data with style
plt.style.use('bmh')
fig, ax = plt.subplots()
ax.set_title(ticker.name)
ax.set_ylabel(ticker.currency.get_identifier())
ax.plot(dates, vector, linewidth=1)
plt.show()

# %%
from pmdata import get_timeseries, get_ticker
from datetime import date
import matplotlib.pyplot as plt
import pandas as pd

# This is how we are getting the time series of a stock
ts = get_timeseries('C40.PA', "adjusted_close")
# We are getting access to the underlying Numpy array in order to graph it
vector = ts.cut2dates(date(2022,1,1), ts.get_end_date())
# We are getting access to the dates in order to display them on the horizontal axis
dates = pd.date_range(date(2022,1,1), ts.get_end_date(), freq='D')
# And we graph the data with style
plt.style.use('bmh')
fig, ax = plt.subplots()
ax.set_title("Amundi CAC 40 ESG")
ax.set_ylabel("EUR")
ax.set_xlabel("Year 2022")
ax.set_xticks([])
ax.plot(dates, vector.get_full_time_series(), linewidth=1)
