# %%
# Sample fundamental data
# This sample code shows the fundamental data available on the platform

from pmdata import FundamentalData

fd = FundamentalData.load("WNC.US")
gen = fd.general()
gen["Name"]+" - "+gen["WebURL"]
# Out:
# 'Wabash National Corporation - https://onewabash.com'

# %%
gen["Description"]
# Out:
# 'Wabash National Corporation designs, manufactures, and distributes engineered solutions for the transportation, logistics, and distribution industries primarily in the United States. The company operates through two segments, Transportation Solutions and Parts & Services. The Transportation Solutions segment provides dry van and platform trailers; refrigerated trailers; converter dollies; van bodies for dry-freight transportation; cutaway van bodies for commercial applications; service bodies; insulated van bodies; stake bodies; refrigerated truck bodies; and used trailers, as well as laminated hardwood oak flooring products. This segment also offers stainless steel and aluminum tank trailers for the dairy, food and beverage, oil, gas, and chemical end markets; dry bulk trailers; and fiberglass reinforced poly tank trailers. The Parts & Services segment provides aftermarket parts and services; aluminum and steel flatbed bodies, shelving for package delivery, partitions, roof racks, 
# ...

# %%
# Industry Classification:
print("Sector:"+gen["GicSector"])
print("Industry Group:"+gen["GicGroup"])
print("Industry:"+gen["GicIndustry"])
print("Sub Industry:"+gen["GicSubIndustry"])
# Out:
# Sector:Industrials
# Industry Group:Capital Goods
# Industry:Machinery
# Sub Industry:Construction Machinery & Heavy Trucks

# %%
fd.highlights()
# Out:
# {'MarketCapitalization': 986689600,
#  'MarketCapitalizationMln': 986.6896,
#  'EBITDA': 140159008,
#  'PERatio': 21.8936,
#  'PEGRatio': 1,
#  'WallStreetTargetPrice': 21.4,
#  'BookValue': 7.492,
#  'DividendShare': 0.32,
#  'DividendYield': 0.0155,
#  'EarningsShare': 0.94,
#  'EPSEstimateCurrentYear': 2.09,
#  'EPSEstimateNextYear': 2.35,
#  'EPSEstimateNextQuarter': 0.62,
#  'EPSEstimateCurrentQuarter': 0.57,
#  'MostRecentQuarter': '2022-09-30',
#  'ProfitMargin': 0.0196,
#  'OperatingMarginTTM': 0.0398,
#  'ReturnOnAssetsTTM': 0.0474,
#  'ReturnOnEquityTTM': 0.1228,
#  'RevenueTTM': 2323956992,
#  'RevenuePerShareTTM': 47.443,
#  'QuarterlyRevenueGrowthYOY': 0.358,
#  'GrossProfitTTM': 196467000,
#  'DilutedEpsTTM': 0.94,
#  'QuarterlyEarningsGrowthYOY': 2.318}

# %%
fd.valuation()
# Out:
# {'TrailingPE': 21.8936,
#  'ForwardPE': 0,
#  'PriceSalesTTM': 0.4246,
#  'PriceBookMRQ': 2.74,
#  'EnterpriseValue': 1355103133,
#  'EnterpriseValueRevenue': 0.5831,
#  'EnterpriseValueEbitda': 10.4176}

# %%
fd.shares_stats()
# Out:
# {'SharesOutstanding': 47944100,
#  'SharesFloat': 47313182,
#  'PercentInsiders': 1.625,
#  'PercentInstitutions': 103.2,
#  'SharesShort': None,
#  'SharesShortPriorMonth': None,
#  'ShortRatio': None,
#  'ShortPercentOutstanding': None,
#  'ShortPercentFloat': None}

# %%
fd.technicals()
# Out:
# {'Beta': 1.5313,
#  '52WeekHigh': 21.68,
#  '52WeekLow': 12.1001,
#  '50DayMA': 16.4848,
#  '200DayMA': 16.0369,
#  'SharesShort': 3636558,
#  'SharesShortPriorMonth': 3399312,
#  'ShortRatio': 10.12,
#  'ShortPercent': 0.1097}

# %%
fd.splits_dividends()
# Out:
# {'ForwardAnnualDividendRate': 0.32,
#  'ForwardAnnualDividendYield': 0.0155,
#  'PayoutRatio': 0.2133,
#  'DividendDate': '2022-10-27',
#  'ExDividendDate': '2022-10-05',
#  'LastSplitFactor': '3:2',
#  'LastSplitDate': '1994-07-29',
#  'NumberDividendsByYear': {'0': {'Year': 1993, 'Count': 4},
#   '1': {'Year': 1994, 'Count': 4},
#   '2': {'Year': 1995, 'Count': 4},
#   '3': {'Year': 1996, 'Count': 4},
#   '4': {'Year': 1997, 'Count': 4},
#   '5': {'Year': 1998, 'Count': 4},
#   '6': {'Year': 1999, 'Count': 4},
#   '7': {'Year': 2000, 'Count': 4},
#   '8': {'Year': 2001, 'Count': 4},
#   '9': {'Year': 2005, 'Count': 4},
#   '10': {'Year': 2006, 'Count': 4},
#   '11': {'Year': 2007, 'Count': 4},
#   '12': {'Year': 2008, 'Count': 3},
#   '13': {'Year': 2017, 'Count': 4},
#   '14': {'Year': 2018, 'Count': 4},
#   '15': {'Year': 2019, 'Count': 5},
#   '16': {'Year': 2020, 'Count': 3},
#   '17': {'Year': 2021, 'Count': 4},
#   '18': {'Year': 2022, 'Count': 4}}}

# %%
fd.holders()
# Out:
# {'Institutions': {'0': {'name': 'Vanguard Group Inc',
#    'date': '2022-06-30',
#    'totalShares': 13.3658,
#    'totalAssets': 0.0025,
#    'currentShares': 6424286,
#    'change': 68880,
#    'change_p': 1.0838},
#   '1': {'name': 'Dimensional Fund Advisors, Inc.',
#    'date': '2022-06-30',
#    'totalShares': 6.7415,
#    'totalAssets': 0.0158,
#    'currentShares': 3240343,
#    'change': -2722,
#    'change_p': -0.0839},
#   '2': {'name': 'Bank of New York Mellon Corp',
#    'date': '2022-06-30',
#    'totalShares': 4.5348,
#    'totalAssets': 0.0068,
#    'currentShares': 2179654,
#    'change': -601949,
#    'change_p': -21.6404},
#   '3': {'name': 'State Street Corporation',
#    'date': '2022-06-30',
#    'totalShares': 3.6912,
#    'totalAssets': 0.0014,
#    'currentShares': 1774206,
#    'change': 3621,
#    'change_p': 0.2045},
#   '4': {'name': 'Victory Capital Management Inc.',
#    'date': '2022-06-30',
#    'totalShares': 3.5856,
#    'totalAssets': 0.0267,
# ...

# %%
fd.insider_transactions()
# Out:
# {'0': {'date': '2022-10-26',
#   'ownerCik': None,
#   'ownerName': 'Dustin T Smith',
#   'transactionDate': '2022-10-26',
#   'transactionCode': 'S',
#   'transactionAmount': 30000,
#   'transactionPrice': 18,
#   'transactionAcquiredDisposed': 'D',
#   'postTransactionAmount': 74004,
#   'secLink': 'http://www.sec.gov/Archives/edgar/data/879526/000106299322021130/xslF345X03/form4.xml'},
#  '1': {'date': '2022-10-25',
#   'ownerCik': None,
#   'ownerName': 'Brent L Yeagy',
#   'transactionDate': '2022-10-25',
#   'transactionCode': 'S',
#   'transactionAmount': 4269,
#   'transactionPrice': 17,
#   'transactionAcquiredDisposed': 'D',
#   'postTransactionAmount': 446824,
#   'secLink': 'http://www.sec.gov/Archives/edgar/data/879526/000106299322021129/xslF345X03/form4.xml'},
#  '2': {'date': '2022-08-01',
#   'ownerCik': None,
#   'ownerName': 'Brent L Yeagy',
#   'transactionDate': '2022-08-01',
#   'transactionCode': 'S',
#   'transactionAmount': 7986,
# ...

# %%
fd.outstanding_shares()
# Out:
# {'annual': {'0': {'date': '2022',
#    'dateFormatted': '2022-12-31',
#    'sharesMln': '49.4020',
#    'shares': 49402000},
#   '1': {'date': '2021',
#    'dateFormatted': '2021-12-31',
#    'sharesMln': '49.4000',
#    'shares': 49400000},
#   '2': {'date': '2020',
#    'dateFormatted': '2020-12-31',
#    'sharesMln': '53.8310',
#    'shares': 53831000},
#   '3': {'date': '2019',
#    'dateFormatted': '2019-12-31',
#    'sharesMln': '54.6130',
#    'shares': 54613000},
#   '4': {'date': '2018',
#    'dateFormatted': '2018-12-31',
#    'sharesMln': '56.2900',
#    'shares': 56290000},
#   '5': {'date': '2017',
#    'dateFormatted': '2017-12-31',
#    'sharesMln': '61.5670',
#    'shares': 61567000},
#   '6': {'date': '2016',
#    'dateFormatted': '2016-12-31',
#    'sharesMln': '63.7010',
#    'shares': 63701000},
#   '7': {'date': '2015',
#    'dateFormatted': '2015-12-31',
#    'sharesMln': '67.2180',
#    'shares': 67218000},
#   '8': {'date': '2014',
# ...

# %%
fd.earnings()
# Out:
# {'History': {'2023-09-30': {'reportDate': '2023-10-24',
#    'date': '2023-09-30',
#    'beforeAfterMarket': 'BeforeMarket',
#    'currency': 'USD',
#    'epsActual': None,
#    'epsEstimate': None,
#    'epsDifference': None,
#    'surprisePercent': None},
#   '2023-06-30': {'reportDate': '2023-07-25',
#    'date': '2023-06-30',
#    'beforeAfterMarket': 'BeforeMarket',
#    'currency': 'USD',
#    'epsActual': None,
#    'epsEstimate': None,
#    'epsDifference': None,
#    'surprisePercent': None},
#   '2023-03-31': {'reportDate': '2023-04-25',
#    'date': '2023-03-31',
#    'beforeAfterMarket': 'BeforeMarket',
#    'currency': 'USD',
#    'epsActual': None,
#    'epsEstimate': None,
#    'epsDifference': None,
#    'surprisePercent': None},
#   '2022-12-31': {'reportDate': '2023-01-31',
#    'date': '2022-12-31',
#    'beforeAfterMarket': 'BeforeMarket',
#    'currency': 'USD',
#    'epsActual': None,
#    'epsEstimate': 0.6153,
#    'epsDifference': None,
# ...

# %%
fd.financials()
# Out:
# {'Balance_Sheet': {'currency_symbol': 'USD',
#   'quarterly': {'2022-09-30': {'date': '2022-09-30',
#     'filing_date': '2022-10-26',
#     'currency_symbol': 'USD',
#     'totalAssets': '1269315000.00',
#     'intangibleAssets': '102415000.00',
#     'earningAssets': None,
#     'otherCurrentAssets': '35251000.00',
#     'totalLiab': '908840000.00',
#     'totalStockholderEquity': '360102000.00',
#     'deferredLongTermLiab': '33100000.00',
#     'otherCurrentLiab': '158315000.00',
#     'commonStock': '765000.00',
#     'capitalStock': '765000.00',
#     'retainedEarnings': '150943000.00',
#     'otherLiab': '67814000.00',
#     'goodWill': '188441000.00',
#     'otherAssets': '51560000.00',
#     'cash': '81478000.00',
#     'cashAndEquivalents': '81478000.00',
#     'totalCurrentLiabilities': '397364000.00',
#     'currentDeferredRevenue': None,
#     'netDebt': '362184000.00',
#     'shortTermDebt': '0.00',
#     'shortLongTermDebt': None,
# ...
